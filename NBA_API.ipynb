# %%
pip install nba_api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()
nba_teams_id = []

for team in nba_teams:
    nba_teams_id.append(team['id'])

# %%
gamefinder = leaguegamefinder.LeagueGameFinder()
all_games = gamefinder.get_data_frames()[0]

# %%
nba_games = all_games[all_games['TEAM_ID'].isin(nba_teams_id)]

nba_games
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0         22023  1610612746               LAC             LA Clippers
# 1         22023  1610612739               CLE     Cleveland Cavaliers
# 3         22023  1610612765               DET         Detroit Pistons
# 4         22023  1610612752               NYK         New York Knicks
# 5         22023  1610612750               MIN  Minnesota Timberwolves
# ...         ...         ...               ...                     ...
# 29798     12019  1610612758               SAC        Sacramento Kings
# 29799     12019  1610612745               HOU         Houston Rockets
# 29800     12019  1610612746               LAC             LA Clippers
# 29802     12019  1610612751               BKN           Brooklyn Nets
# 29806     12019  1610612745               HOU         Houston Rockets
#
#           GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# ...

# %%
#this_season = nba_games[nba_games.SEASON_ID.str[-4:] == '2023']
#this_season['GAME_DATE'] = pd.to_datetime(this_season['GAME_DATE'])
#this_season_beforeJan = this_season[this_season.GAME_DATE < pd.Timestamp(2024,4,8)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 this_season = nba_games[nba_games.SEASON_ID.str[-4:] == '2023']
# ----> 2 this_season['GAME_DATE'] = pd.to_datetime(this_season['GAME_DATE'])
#
# NameError: name 'pd' is not defined

# %%
#this_season_beforeJan

# %%
nba_games.to_csv("2019to2024nbagamestats.csv", index=False)
